# %%
import numpy as np
count = 0                            # счетчик попыток
number = np.random.randint(1,100) #загадали число
print ("Загадано число от 1 до 100")

def game_core_v2(number):
    '''Сначала устанавливаем любое random число, а потом уменьшаем или увеличиваем его в зависимости от того, больше оно или меньше нужного.
       Функция принимает загаданное число и возвращает число попыток'''
    left = 1
    right = 100
    count = 1
    predict = (left+right) // 2      # предполагаемое число
    print("Предполагаемое число:", predict)
    while number != predict:
        count+=1
        if number > predict: 
            print (f"Угадываемое число больше {predict} ")
            left = predict
            predict = (predict + right) // 2
        elif number < predict:
            print(f"Угадываемое число меньше {predict} ")
            right = predict
            predict = (predict + left) // 2
        print("Предполагаемое число:", predict)
    print(f"Вы угадали число {number} за {count} попыток. \n")
    return(count) # выход из цикла, если угадали


def score_game(game_core):
    '''Запускаем игру 1000 раз, чтобы узнать, как быстро игра угадывает число'''
    count_ls = []
    np.random.seed(1)  # фиксируем RANDOM SEED, чтобы ваш эксперимент был воспроизводим!
    random_array = np.random.randint(left,right, size=(1000))
    for number in random_array:
        count_ls.append(game_core(number))
    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за {score} попыток")
    return(score)

# запускаем
score_game(game_core_v2)
# Out:
# Загадано число от 1 до 100
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число меньше 43
# Предполагаемое число: 40
# Угадываемое число меньше 40
# Предполагаемое число: 38
# Вы угадали число 38 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Вы угадали число 13 за 3 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Вы угадали число 73 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Вы угадали число 10 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Угадываемое число меньше 78
# Предполагаемое число: 76
# Вы угадали число 76 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число больше 4
# Предполагаемое число: 5
# Угадываемое число больше 5
# Предполагаемое число: 6
# Вы угадали число 6 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Угадываемое число больше 78
# Предполагаемое число: 79
# Угадываемое число больше 79
# Предполагаемое число: 80
# Вы угадали число 80 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число меньше 68
# Предполагаемое число: 65
# Вы угадали число 65 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число меньше 19
# Предполагаемое число: 16
# Угадываемое число больше 16
# Предполагаемое число: 17
# Вы угадали число 17 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число меньше 4
# Предполагаемое число: 2
# Вы угадали число 2 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Угадываемое число меньше 78
# Предполагаемое число: 76
# Угадываемое число больше 76
# Предполагаемое число: 77
# Вы угадали число 77 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Угадываемое число меньше 73
# Предполагаемое число: 72
# Вы угадали число 72 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Вы угадали число 7 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Угадываемое число меньше 28
# Предполагаемое число: 26
# Вы угадали число 26 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Угадываемое число меньше 53
# Предполагаемое число: 51
# Вы угадали число 51 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число меньше 22
# Предполагаемое число: 20
# Угадываемое число больше 20
# Предполагаемое число: 21
# Вы угадали число 21 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Вы угадали число 19 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число больше 81
# Предполагаемое число: 84
# Угадываемое число больше 84
# Предполагаемое число: 85
# Вы угадали число 85 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число больше 10
# Предполагаемое число: 11
# Угадываемое число больше 11
# Предполагаемое число: 12
# Вы угадали число 12 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Угадываемое число больше 28
# Предполагаемое число: 29
# Вы угадали число 29 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Угадываемое число больше 28
# Предполагаемое число: 29
# Угадываемое число больше 29
# Предполагаемое число: 30
# Вы угадали число 30 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число меньше 19
# Предполагаемое число: 16
# Угадываемое число меньше 16
# Предполагаемое число: 14
# Угадываемое число больше 14
# Предполагаемое число: 15
# Вы угадали число 15 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Угадываемое число меньше 53
# Предполагаемое число: 51
# Вы угадали число 51 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число меньше 71
# Предполагаемое число: 69
# Вы угадали число 69 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число меньше 93
# Предполагаемое число: 90
# Угадываемое число меньше 90
# Предполагаемое число: 88
# Вы угадали число 88 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число меньше 93
# Предполагаемое число: 90
# Угадываемое число меньше 90
# Предполагаемое число: 88
# Вы угадали число 88 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число меньше 96
# Предполагаемое число: 94
# Угадываемое число больше 94
# Предполагаемое число: 95
# Вы угадали число 95 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число больше 96
# Предполагаемое число: 98
# Угадываемое число меньше 98
# Предполагаемое число: 97
# Вы угадали число 97 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Вы угадали число 87 за 3 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число меньше 19
# Предполагаемое число: 16
# Угадываемое число меньше 16
# Предполагаемое число: 14
# Вы угадали число 14 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Вы угадали число 10 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число меньше 10
# Предполагаемое число: 8
# Вы угадали число 8 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число меньше 68
# Предполагаемое число: 65
# Угадываемое число меньше 65
# Предполагаемое число: 63
# Угадываемое число больше 63
# Предполагаемое число: 64
# Вы угадали число 64 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Вы угадали число 62 за 3 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число больше 22
# Предполагаемое число: 23
# Вы угадали число 23 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число больше 56
# Предполагаемое число: 59
# Угадываемое число меньше 59
# Предполагаемое число: 57
# Угадываемое число больше 57
# Предполагаемое число: 58
# Вы угадали число 58 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число меньше 4
# Предполагаемое число: 2
# Вы угадали число 2 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число меньше 4
# Предполагаемое число: 2
# Угадываемое число меньше 2
# Предполагаемое число: 1
# Вы угадали число 1 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число больше 56
# Предполагаемое число: 59
# Угадываемое число больше 59
# Предполагаемое число: 60
# Угадываемое число больше 60
# Предполагаемое число: 61
# Вы угадали число 61 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число больше 81
# Предполагаемое число: 84
# Угадываемое число меньше 84
# Предполагаемое число: 82
# Вы угадали число 82 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число меньше 10
# Предполагаемое число: 8
# Угадываемое число больше 8
# Предполагаемое число: 9
# Вы угадали число 9 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число меньше 93
# Предполагаемое число: 90
# Угадываемое число меньше 90
# Предполагаемое число: 88
# Угадываемое число больше 88
# Предполагаемое число: 89
# Вы угадали число 89 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число меньше 19
# Предполагаемое число: 16
# Угадываемое число меньше 16
# Предполагаемое число: 14
# Вы угадали число 14 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Угадываемое число больше 46
# Предполагаемое число: 48
# Вы угадали число 48 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Вы угадали число 73 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Вы угадали число 31 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Угадываемое число меньше 73
# Предполагаемое число: 72
# Вы угадали число 72 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Вы угадали число 4 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Вы угадали число 71 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Вы угадали число 22 за 5 попыток.
#
# Предполагаемое число: 50
# Вы угадали число 50 за 1 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число больше 56
# Предполагаемое число: 59
# Угадываемое число меньше 59
# Предполагаемое число: 57
# Угадываемое число больше 57
# Предполагаемое число: 58
# Вы угадали число 58 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Вы угадали число 4 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число меньше 71
# Предполагаемое число: 69
# Вы угадали число 69 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Вы угадали число 25 за 2 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Угадываемое число меньше 46
# Предполагаемое число: 44
# Вы угадали число 44 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Угадываемое число меньше 78
# Предполагаемое число: 76
# Угадываемое число больше 76
# Предполагаемое число: 77
# Вы угадали число 77 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Угадываемое число меньше 28
# Предполагаемое число: 26
# Угадываемое число больше 26
# Предполагаемое число: 27
# Вы угадали число 27 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Вы угадали число 53 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Вы угадали число 81 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число меньше 43
# Предполагаемое число: 40
# Угадываемое число больше 40
# Предполагаемое число: 41
# Угадываемое число больше 41
# Предполагаемое число: 42
# Вы угадали число 42 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число больше 81
# Предполагаемое число: 84
# Угадываемое число меньше 84
# Предполагаемое число: 82
# Угадываемое число больше 82
# Предполагаемое число: 83
# Вы угадали число 83 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число меньше 19
# Предполагаемое число: 16
# Вы угадали число 16 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число меньше 68
# Предполагаемое число: 65
# Вы угадали число 65 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число меньше 71
# Предполагаемое число: 69
# Вы угадали число 69 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Угадываемое число меньше 28
# Предполагаемое число: 26
# Вы угадали число 26 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число больше 96
# Предполагаемое число: 98
# Угадываемое число больше 98
# Предполагаемое число: 99
# Вы угадали число 99 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число меньше 93
# Предполагаемое число: 90
# Угадываемое число меньше 90
# Предполагаемое число: 88
# Вы угадали число 88 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число меньше 10
# Предполагаемое число: 8
# Вы угадали число 8 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Угадываемое число меньше 28
# Предполагаемое число: 26
# Угадываемое число больше 26
# Предполагаемое число: 27
# Вы угадали число 27 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Угадываемое число меньше 28
# Предполагаемое число: 26
# Вы угадали число 26 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число больше 22
# Предполагаемое число: 23
# Вы угадали число 23 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Вы угадали число 10 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Вы угадали число 68 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число больше 22
# Предполагаемое число: 23
# Угадываемое число больше 23
# Предполагаемое число: 24
# Вы угадали число 24 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Вы угадали число 28 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число меньше 43
# Предполагаемое число: 40
# Угадываемое число меньше 40
# Предполагаемое число: 38
# Вы угадали число 38 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число больше 56
# Предполагаемое число: 59
# Угадываемое число меньше 59
# Предполагаемое число: 57
# Угадываемое число больше 57
# Предполагаемое число: 58
# Вы угадали число 58 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число больше 81
# Предполагаемое число: 84
# Вы угадали число 84 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число меньше 43
# Предполагаемое число: 40
# Угадываемое число меньше 40
# Предполагаемое число: 38
# Угадываемое число больше 38
# Предполагаемое число: 39
# Вы угадали число 39 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число меньше 10
# Предполагаемое число: 8
# Угадываемое число больше 8
# Предполагаемое число: 9
# Вы угадали число 9 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число больше 31
# Предполагаемое число: 34
# Угадываемое число меньше 34
# Предполагаемое число: 32
# Угадываемое число больше 32
# Предполагаемое число: 33
# Вы угадали число 33 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число больше 31
# Предполагаемое число: 34
# Угадываемое число больше 34
# Предполагаемое число: 35
# Вы угадали число 35 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число больше 10
# Предполагаемое число: 11
# Вы угадали число 11 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число больше 22
# Предполагаемое число: 23
# Угадываемое число больше 23
# Предполагаемое число: 24
# Вы угадали число 24 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число меньше 19
# Предполагаемое число: 16
# Вы угадали число 16 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число меньше 93
# Предполагаемое число: 90
# Угадываемое число меньше 90
# Предполагаемое число: 88
# Вы угадали число 88 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Угадываемое число меньше 28
# Предполагаемое число: 26
# Вы угадали число 26 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Угадываемое число меньше 73
# Предполагаемое число: 72
# Вы угадали число 72 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Вы угадали число 93 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Вы угадали число 75 за 2 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число меньше 68
# Предполагаемое число: 65
# Угадываемое число меньше 65
# Предполагаемое число: 63
# Вы угадали число 63 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Угадываемое число больше 46
# Предполагаемое число: 48
# Угадываемое число меньше 48
# Предполагаемое число: 47
# Вы угадали число 47 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число больше 31
# Предполагаемое число: 34
# Угадываемое число меньше 34
# Предполагаемое число: 32
# Угадываемое число больше 32
# Предполагаемое число: 33
# Вы угадали число 33 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число меньше 93
# Предполагаемое число: 90
# Угадываемое число меньше 90
# Предполагаемое число: 88
# Угадываемое число больше 88
# Предполагаемое число: 89
# Вы угадали число 89 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число больше 22
# Предполагаемое число: 23
# Угадываемое число больше 23
# Предполагаемое число: 24
# Вы угадали число 24 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Вы угадали число 56 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число меньше 68
# Предполагаемое число: 65
# Угадываемое число больше 65
# Предполагаемое число: 66
# Вы угадали число 66 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Вы угадали число 78 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Вы угадали число 4 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число меньше 4
# Предполагаемое число: 2
# Угадываемое число меньше 2
# Предполагаемое число: 1
# Вы угадали число 1 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Вы угадали число 78 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Вы угадали число 7 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Вы угадали число 53 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число больше 81
# Предполагаемое число: 84
# Угадываемое число больше 84
# Предполагаемое число: 85
# Угадываемое число больше 85
# Предполагаемое число: 86
# Вы угадали число 86 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Вы угадали число 71 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число меньше 4
# Предполагаемое число: 2
# Угадываемое число больше 2
# Предполагаемое число: 3
# Вы угадали число 3 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Угадываемое число меньше 78
# Предполагаемое число: 76
# Угадываемое число больше 76
# Предполагаемое число: 77
# Вы угадали число 77 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число меньше 93
# Предполагаемое число: 90
# Угадываемое число больше 90
# Предполагаемое число: 91
# Угадываемое число больше 91
# Предполагаемое число: 92
# Вы угадали число 92 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Вы угадали число 22 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Угадываемое число меньше 78
# Предполагаемое число: 76
# Вы угадали число 76 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число меньше 10
# Предполагаемое число: 8
# Вы угадали число 8 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Вы угадали число 78 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Вы угадали число 73 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Угадываемое число меньше 78
# Предполагаемое число: 76
# Вы угадали число 76 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Угадываемое число меньше 78
# Предполагаемое число: 76
# Угадываемое число больше 76
# Предполагаемое число: 77
# Вы угадали число 77 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Угадываемое число меньше 46
# Предполагаемое число: 44
# Вы угадали число 44 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число меньше 22
# Предполагаемое число: 20
# Угадываемое число больше 20
# Предполагаемое число: 21
# Вы угадали число 21 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Вы угадали число 31 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Вы угадали число 37 за 3 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число меньше 10
# Предполагаемое число: 8
# Вы угадали число 8 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Вы угадали число 46 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число меньше 71
# Предполагаемое число: 69
# Вы угадали число 69 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число больше 56
# Предполагаемое число: 59
# Угадываемое число меньше 59
# Предполагаемое число: 57
# Угадываемое число больше 57
# Предполагаемое число: 58
# Вы угадали число 58 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число больше 81
# Предполагаемое число: 84
# Угадываемое число меньше 84
# Предполагаемое число: 82
# Угадываемое число больше 82
# Предполагаемое число: 83
# Вы угадали число 83 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число больше 96
# Предполагаемое число: 98
# Угадываемое число меньше 98
# Предполагаемое число: 97
# Вы угадали число 97 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число меньше 19
# Предполагаемое число: 16
# Угадываемое число меньше 16
# Предполагаемое число: 14
# Вы угадали число 14 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число больше 10
# Предполагаемое число: 11
# Вы угадали число 11 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число больше 22
# Предполагаемое число: 23
# Угадываемое число больше 23
# Предполагаемое число: 24
# Вы угадали число 24 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число больше 81
# Предполагаемое число: 84
# Угадываемое число меньше 84
# Предполагаемое число: 82
# Вы угадали число 82 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число меньше 10
# Предполагаемое число: 8
# Вы угадали число 8 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Вы угадали число 25 за 2 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Вы угадали число 75 за 2 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Вы угадали число 93 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число меньше 22
# Предполагаемое число: 20
# Угадываемое число больше 20
# Предполагаемое число: 21
# Вы угадали число 21 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число больше 31
# Предполагаемое число: 34
# Угадываемое число меньше 34
# Предполагаемое число: 32
# Угадываемое число больше 32
# Предполагаемое число: 33
# Вы угадали число 33 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Вы угадали число 13 за 3 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число меньше 68
# Предполагаемое число: 65
# Угадываемое число больше 65
# Предполагаемое число: 66
# Вы угадали число 66 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число меньше 96
# Предполагаемое число: 94
# Угадываемое число больше 94
# Предполагаемое число: 95
# Вы угадали число 95 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число больше 56
# Предполагаемое число: 59
# Угадываемое число больше 59
# Предполагаемое число: 60
# Угадываемое число больше 60
# Предполагаемое число: 61
# Вы угадали число 61 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Вы угадали число 25 за 2 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число больше 81
# Предполагаемое число: 84
# Угадываемое число меньше 84
# Предполагаемое число: 82
# Угадываемое число больше 82
# Предполагаемое число: 83
# Вы угадали число 83 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число больше 96
# Предполагаемое число: 98
# Вы угадали число 98 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число меньше 4
# Предполагаемое число: 2
# Угадываемое число больше 2
# Предполагаемое число: 3
# Вы угадали число 3 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Вы угадали число 93 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число больше 96
# Предполагаемое число: 98
# Угадываемое число больше 98
# Предполагаемое число: 99
# Вы угадали число 99 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число больше 7
# Предполагаемое число: 10
# Угадываемое число больше 10
# Предполагаемое число: 11
# Вы угадали число 11 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Угадываемое число больше 53
# Предполагаемое число: 54
# Угадываемое число больше 54
# Предполагаемое число: 55
# Вы угадали число 55 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число больше 96
# Предполагаемое число: 98
# Угадываемое число меньше 98
# Предполагаемое число: 97
# Вы угадали число 97 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число больше 81
# Предполагаемое число: 84
# Угадываемое число меньше 84
# Предполагаемое число: 82
# Угадываемое число больше 82
# ...
# Предполагаемое число: 43
# Вы угадали число 43 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Угадываемое число больше 46
# Предполагаемое число: 48
# Угадываемое число меньше 48
# Предполагаемое число: 47
# Вы угадали число 47 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Вы угадали число 22 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Угадываемое число меньше 53
# Предполагаемое число: 51
# Угадываемое число больше 51
# Предполагаемое число: 52
# Вы угадали число 52 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Угадываемое число больше 73
# Предполагаемое число: 74
# Вы угадали число 74 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Вы угадали число 43 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число меньше 19
# Предполагаемое число: 16
# Угадываемое число меньше 16
# Предполагаемое число: 14
# Вы угадали число 14 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Вы угадали число 19 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число больше 22
# Предполагаемое число: 23
# Угадываемое число больше 23
# Предполагаемое число: 24
# Вы угадали число 24 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Вы угадали число 46 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Вы угадали число 96 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Вы угадали число 53 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число больше 31
# Предполагаемое число: 34
# Вы угадали число 34 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Угадываемое число больше 53
# Предполагаемое число: 54
# Угадываемое число больше 54
# Предполагаемое число: 55
# Вы угадали число 55 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число меньше 19
# Предполагаемое число: 16
# Угадываемое число меньше 16
# Предполагаемое число: 14
# Угадываемое число больше 14
# Предполагаемое число: 15
# Вы угадали число 15 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число больше 56
# Предполагаемое число: 59
# Угадываемое число меньше 59
# Предполагаемое число: 57
# Угадываемое число больше 57
# Предполагаемое число: 58
# Вы угадали число 58 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Вы угадали число 62 за 3 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число меньше 43
# Предполагаемое число: 40
# Угадываемое число больше 40
# Предполагаемое число: 41
# Вы угадали число 41 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Вы угадали число 73 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число меньше 68
# Предполагаемое число: 65
# Угадываемое число больше 65
# Предполагаемое число: 66
# Вы угадали число 66 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число больше 13
# Предполагаемое число: 19
# Угадываемое число больше 19
# Предполагаемое число: 22
# Угадываемое число больше 22
# Предполагаемое число: 23
# Вы угадали число 23 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число меньше 4
# Предполагаемое число: 2
# Угадываемое число больше 2
# Предполагаемое число: 3
# Вы угадали число 3 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Вы угадали число 87 за 3 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число меньше 4
# Предполагаемое число: 2
# Вы угадали число 2 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Вы угадали число 73 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Угадываемое число меньше 53
# Предполагаемое число: 51
# Угадываемое число больше 51
# Предполагаемое число: 52
# Вы угадали число 52 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число больше 68
# Предполагаемое число: 71
# Угадываемое число больше 71
# Предполагаемое число: 73
# Угадываемое число меньше 73
# Предполагаемое число: 72
# Вы угадали число 72 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число меньше 93
# Предполагаемое число: 90
# Угадываемое число меньше 90
# Предполагаемое число: 88
# Вы угадали число 88 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Вы угадали число 78 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число меньше 68
# Предполагаемое число: 65
# Угадываемое число меньше 65
# Предполагаемое число: 63
# Вы угадали число 63 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Угадываемое число больше 46
# Предполагаемое число: 48
# Угадываемое число больше 48
# Предполагаемое число: 49
# Вы угадали число 49 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число меньше 4
# Предполагаемое число: 2
# Угадываемое число меньше 2
# Предполагаемое число: 1
# Вы угадали число 1 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Вы угадали число 43 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число меньше 43
# Предполагаемое число: 40
# Вы угадали число 40 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Вы угадали число 4 за 5 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число больше 56
# Предполагаемое число: 59
# Угадываемое число меньше 59
# Предполагаемое число: 57
# Угадываемое число больше 57
# Предполагаемое число: 58
# Вы угадали число 58 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Угадываемое число меньше 46
# Предполагаемое число: 44
# Вы угадали число 44 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число меньше 56
# Предполагаемое число: 53
# Угадываемое число больше 53
# Предполагаемое число: 54
# Вы угадали число 54 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число больше 37
# Предполагаемое число: 43
# Угадываемое число больше 43
# Предполагаемое число: 46
# Угадываемое число меньше 46
# Предполагаемое число: 44
# Вы угадали число 44 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Вы угадали число 75 за 2 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число больше 96
# Предполагаемое число: 98
# Угадываемое число больше 98
# Предполагаемое число: 99
# Вы угадали число 99 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число больше 93
# Предполагаемое число: 96
# Угадываемое число больше 96
# Предполагаемое число: 98
# Вы угадали число 98 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число меньше 87
# Предполагаемое число: 81
# Угадываемое число меньше 81
# Предполагаемое число: 78
# Угадываемое число меньше 78
# Предполагаемое число: 76
# Вы угадали число 76 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число меньше 62
# Предполагаемое число: 56
# Угадываемое число больше 56
# Предполагаемое число: 59
# Угадываемое число больше 59
# Предполагаемое число: 60
# Вы угадали число 60 за 6 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Угадываемое число меньше 68
# Предполагаемое число: 65
# Угадываемое число больше 65
# Предполагаемое число: 66
# Угадываемое число больше 66
# Предполагаемое число: 67
# Вы угадали число 67 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Вы угадали число 75 за 2 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число больше 75
# Предполагаемое число: 87
# Угадываемое число больше 87
# Предполагаемое число: 93
# Угадываемое число меньше 93
# Предполагаемое число: 90
# Угадываемое число больше 90
# Предполагаемое число: 91
# Угадываемое число больше 91
# Предполагаемое число: 92
# Вы угадали число 92 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число меньше 25
# Предполагаемое число: 13
# Угадываемое число меньше 13
# Предполагаемое число: 7
# Угадываемое число меньше 7
# Предполагаемое число: 4
# Угадываемое число больше 4
# Предполагаемое число: 5
# Угадываемое число больше 5
# Предполагаемое число: 6
# Вы угадали число 6 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число меньше 31
# Предполагаемое число: 28
# Угадываемое число меньше 28
# Предполагаемое число: 26
# Угадываемое число больше 26
# Предполагаемое число: 27
# Вы угадали число 27 за 7 попыток.
#
# Предполагаемое число: 50
# Угадываемое число больше 50
# Предполагаемое число: 75
# Угадываемое число меньше 75
# Предполагаемое число: 62
# Угадываемое число больше 62
# Предполагаемое число: 68
# Вы угадали число 68 за 4 попыток.
#
# Предполагаемое число: 50
# Угадываемое число меньше 50
# Предполагаемое число: 25
# Угадываемое число больше 25
# Предполагаемое число: 37
# Угадываемое число меньше 37
# Предполагаемое число: 31
# Угадываемое число больше 31
# Предполагаемое число: 34
# Угадываемое число меньше 34
# Предполагаемое число: 32
# Вы угадали число 32 за 6 попыток.
#
# Ваш алгоритм угадывает число в среднем за 5 попыток
# 5
